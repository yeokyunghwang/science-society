# %%
import warnings
warnings.filterwarnings(
    "ignore",
    message="`tokenizer` is deprecated and will be removed in version 5.0.0"
)

import transformers
transformers.utils.logging.set_verbosity_error()

# %%
# %%bash
# cd /root/science-society
#
# START_MODE="per_node"
# PER_NODE_SCHEME="degree"
#
# if [ "${START_MODE}" = "per_node" ]; then
#   MODE_TAG="start=${START_MODE}__scheme=${PER_NODE_SCHEME}"
# else
#   MODE_TAG="start=${START_MODE}"
# fi
#
# CORPUS_DIR="./corpus/${MODE_TAG}"
# MAP_DIR="./tokenizer/${MODE_TAG}"
# mkdir -p "${CORPUS_DIR}" "${MAP_DIR}"
#
# for Y in 1990 1991 1992 1993 1994 1995; do
#   python ./scripts/make_walk_corpus_encoded.py \
#     --pkl ./data/news/news_network_${Y}_m0.0-M1.0.pkl \
#     --out "${CORPUS_DIR}/news_${Y}.txt" \
#     --walk_length 20 --num_walks 20000 --seed 42 \
#     --start_mode "${START_MODE}" --per_node_scheme "${PER_NODE_SCHEME}" \
#     --mapping_json "${MAP_DIR}/news_mapping_${Y}.json"
#
#   python ./scripts/make_walk_corpus_encoded.py \
#     --pkl ./data/paper/paper_network_${Y}_m0.0-M0.5.pkl \
#     --out "${CORPUS_DIR}/paper_${Y}.txt" \
#     --walk_length 20 --num_walks 20000 --seed 42 \
#     --start_mode "${START_MODE}" --per_node_scheme "${PER_NODE_SCHEME}" \
#     --mapping_json "${MAP_DIR}/paper_mapping_${Y}.json"
# done
# Out:
# [OK] start_mode=per_node scheme=degree wrote 20000 walks to ./corpus/start=per_node__scheme=degree/news_1990.txt
# [OK] start_mode=per_node scheme=degree wrote 20000 walks to ./corpus/start=per_node__scheme=degree/paper_1990.txt
# [OK] start_mode=per_node scheme=degree wrote 20000 walks to ./corpus/start=per_node__scheme=degree/news_1991.txt
# [OK] start_mode=per_node scheme=degree wrote 20000 walks to ./corpus/start=per_node__scheme=degree/paper_1991.txt
# [OK] start_mode=per_node scheme=degree wrote 20000 walks to ./corpus/start=per_node__scheme=degree/news_1992.txt
# [OK] start_mode=per_node scheme=degree wrote 20000 walks to ./corpus/start=per_node__scheme=degree/paper_1992.txt
# [OK] start_mode=per_node scheme=degree wrote 20000 walks to ./corpus/start=per_node__scheme=degree/news_1993.txt
# [OK] start_mode=per_node scheme=degree wrote 20000 walks to ./corpus/start=per_node__scheme=degree/paper_1993.txt
# [OK] start_mode=per_node scheme=degree wrote 20000 walks to ./corpus/start=per_node__scheme=degree/news_1994.txt
# [OK] start_mode=per_node scheme=degree wrote 20000 walks to ./corpus/start=per_node__scheme=degree/paper_1994.txt
# [OK] start_mode=per_node scheme=degree wrote 20000 walks to ./corpus/start=per_node__scheme=degree/news_1995.txt
# [OK] start_mode=per_node scheme=degree wrote 20000 walks to ./corpus/start=per_node__scheme=degree/paper_1995.txt

# %%
# %%bash
# cd /root/science-society
#
# START_MODE="per_node"
# PER_NODE_SCHEME="degree"
#
# if [ "${START_MODE}" = "per_node" ]; then
#   MODE_TAG="start=${START_MODE}__scheme=${PER_NODE_SCHEME}"
# else
#   MODE_TAG="start=${START_MODE}"
# fi
#
# CORPUS_DIR="./corpus/${MODE_TAG}"
# DATASET_DIR="./datasets/${MODE_TAG}"
# mkdir -p "${DATASET_DIR}"
#
# python scripts/make_hf_dataset.py \
#   --corpus_root "${CORPUS_DIR}" \
#   --out_dir "${DATASET_DIR}" \
#   --years 1990 1991 1992 1993 1994 1995 \
#   --domains news paper
# Out:
# Saving the dataset (1/1 shards): 100%|██████████| 20000/20000 [00:00<00:00, 1598347.66 examples/s]
# [OK] saved news_1990 -> ./datasets/start=per_node__scheme=degree/news_1990 (n=20000)
# Saving the dataset (1/1 shards): 100%|██████████| 20000/20000 [00:00<00:00, 1586587.99 examples/s]
# [OK] saved paper_1990 -> ./datasets/start=per_node__scheme=degree/paper_1990 (n=20000)
# Saving the dataset (1/1 shards): 100%|██████████| 20000/20000 [00:00<00:00, 1649255.45 examples/s]
# [OK] saved news_1991 -> ./datasets/start=per_node__scheme=degree/news_1991 (n=20000)
# Saving the dataset (1/1 shards): 100%|██████████| 20000/20000 [00:00<00:00, 1588721.43 examples/s]
# [OK] saved paper_1991 -> ./datasets/start=per_node__scheme=degree/paper_1991 (n=20000)
# Saving the dataset (1/1 shards): 100%|██████████| 20000/20000 [00:00<00:00, 1641895.44 examples/s]
# [OK] saved news_1992 -> ./datasets/start=per_node__scheme=degree/news_1992 (n=20000)
# Saving the dataset (1/1 shards): 100%|██████████| 20000/20000 [00:00<00:00, 1510834.79 examples/s]
# [OK] saved paper_1992 -> ./datasets/start=per_node__scheme=degree/paper_1992 (n=20000)
# Saving the dataset (1/1 shards): 100%|██████████| 20000/20000 [00:00<00:00, 1664010.16 examples/s]
# [OK] saved news_1993 -> ./datasets/start=per_node__scheme=degree/news_1993 (n=20000)
# Saving the dataset (1/1 shards): 100%|██████████| 20000/20000 [00:00<00:00, 1521798.16 examples/s]
# [OK] saved paper_1993 -> ./datasets/start=per_node__scheme=degree/paper_1993 (n=20000)
# Saving the dataset (1/1 shards): 100%|██████████| 20000/20000 [00:00<00:00, 1637057.10 examples/s]
# [OK] saved news_1994 -> ./datasets/start=per_node__scheme=degree/news_1994 (n=20000)
# Saving the dataset (1/1 shards): 100%|██████████| 20000/20000 [00:00<00:00, 1480987.25 examples/s]
# [OK] saved paper_1994 -> ./datasets/start=per_node__scheme=degree/paper_1994 (n=20000)
# Saving the dataset (1/1 shards): 100%|██████████| 20000/20000 [00:00<00:00, 1531830.10 examples/s]
# [OK] saved news_1995 -> ./datasets/start=per_node__scheme=degree/news_1995 (n=20000)
# Saving the dataset (1/1 shards): 100%|██████████| 20000/20000 [00:00<00:00, 1487658.37 examples/s]
# [OK] saved paper_1995 -> ./datasets/start=per_node__scheme=degree/paper_1995 (n=20000)

# %%
# %%bash
# cd /root/science-society
#
# START_MODE="per_node"
# PER_NODE_SCHEME="degree"
# if [ "${START_MODE}" = "per_node" ]; then
#   MODE_TAG="start=${START_MODE}__scheme=${PER_NODE_SCHEME}"
# else
#   MODE_TAG="start=${START_MODE}"
# fi
#
# y=1990
# DATASET_DIR="./datasets/${MODE_TAG}"
# CKPT_DIR="./checkpoints/${MODE_TAG}"
# mkdir -p "${CKPT_DIR}"
#
# python scripts/train_mlm_preinit.py \
#   --dataset_dir "${DATASET_DIR}/news_${y}" \
#   --node_vocab_txt ./tokenizer/concept_vocab_encoded.txt \
#   --output_dir "${CKPT_DIR}/news_${y}_seed" \
#   --num_train_epochs 5 \
#   --learning_rate 5e-5 \
#   --mlm_prob 0.15
#
# python scripts/train_mlm_preinit.py \
#   --dataset_dir "${DATASET_DIR}/paper_${y}" \
#   --node_vocab_txt ./tokenizer/concept_vocab_encoded.txt \
#   --output_dir "${CKPT_DIR}/paper_${y}_seed" \
#   --num_train_epochs 5 \
#   --learning_rate 5e-5 \
#   --mlm_prob 0.15
# Out:
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [vocab] loaded node tokens: 22577
# [tokenizer] added tokens: 22577 (new vocab size=50345)
# [init] initialized added node token embeddings: 19823, fallback_to_UNK: 0
# Map: 100%|██████████| 20000/20000 [00:00<00:00, 27320.66 examples/s]
# [mask] node_token_ids in tokenizer: 22577
# 100%|██████████| 3095/3095 [03:04<00:00, 16.75it/s]
# {'loss': 7.9307, 'grad_norm': 8.476469039916992, 'learning_rate': 4.975936748023376e-05, 'epoch': 0.32}
# {'loss': 6.8197, 'grad_norm': 6.869620323181152, 'learning_rate': 4.6321760055001723e-05, 'epoch': 0.65}
# {'loss': 6.6206, 'grad_norm': 8.264772415161133, 'learning_rate': 4.288415262976968e-05, 'epoch': 0.97}
# {'loss': 6.4218, 'grad_norm': 7.83885383605957, 'learning_rate': 3.9446545204537646e-05, 'epoch': 1.29}
# {'loss': 6.2753, 'grad_norm': 8.379073143005371, 'learning_rate': 3.600893777930561e-05, 'epoch': 1.62}
# {'loss': 6.1651, 'grad_norm': 8.86072063446045, 'learning_rate': 3.257133035407357e-05, 'epoch': 1.94}
# {'loss': 6.0564, 'grad_norm': 9.469405174255371, 'learning_rate': 2.913372292884153e-05, 'epoch': 2.26}
# {'loss': 5.9395, 'grad_norm': 9.132473945617676, 'learning_rate': 2.569611550360949e-05, 'epoch': 2.58}
# {'loss': 5.8618, 'grad_norm': 8.650469779968262, 'learning_rate': 2.225850807837745e-05, 'epoch': 2.91}
# {'loss': 5.7618, 'grad_norm': 10.042160034179688, 'learning_rate': 1.8820900653145413e-05, 'epoch': 3.23}
# {'loss': 5.7243, 'grad_norm': 8.33537483215332, 'learning_rate': 1.5383293227913374e-05, 'epoch': 3.55}
# {'loss': 5.6865, 'grad_norm': 9.07657241821289, 'learning_rate': 1.1945685802681335e-05, 'epoch': 3.88}
# {'loss': 5.6373, 'grad_norm': 9.66919994354248, 'learning_rate': 8.508078377449295e-06, 'epoch': 4.2}
# {'loss': 5.5697, 'grad_norm': 9.721020698547363, 'learning_rate': 5.070470952217257e-06, 'epoch': 4.52}
# {'loss': 5.5718, 'grad_norm': 11.369430541992188, 'learning_rate': 1.6328635269852184e-06, 'epoch': 4.85}
# {'train_runtime': 184.7624, 'train_samples_per_second': 535.823, 'train_steps_per_second': 16.751, 'train_loss': 6.1184542506499895, 'epoch': 5.0}
# [done] baseline saved to: ./checkpoints/start=per_node__scheme=degree/news_1990_seed
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [vocab] loaded node tokens: 22577
# [tokenizer] added tokens: 22577 (new vocab size=50345)
# [init] initialized added node token embeddings: 19823, fallback_to_UNK: 0
# Map: 100%|██████████| 20000/20000 [00:00<00:00, 30231.97 examples/s]
# [mask] node_token_ids in tokenizer: 22577
# 100%|██████████| 3095/3095 [03:04<00:00, 16.76it/s]
# {'loss': 9.1048, 'grad_norm': 8.945556640625, 'learning_rate': 4.975936748023376e-05, 'epoch': 0.32}
# {'loss': 8.1501, 'grad_norm': 7.651319980621338, 'learning_rate': 4.6321760055001723e-05, 'epoch': 0.65}
# {'loss': 7.9542, 'grad_norm': 7.676267623901367, 'learning_rate': 4.288415262976968e-05, 'epoch': 0.97}
# {'loss': 7.7789, 'grad_norm': 7.2110981941223145, 'learning_rate': 3.9446545204537646e-05, 'epoch': 1.29}
# {'loss': 7.7018, 'grad_norm': 9.12881088256836, 'learning_rate': 3.600893777930561e-05, 'epoch': 1.62}
# {'loss': 7.6291, 'grad_norm': 8.238570213317871, 'learning_rate': 3.257133035407357e-05, 'epoch': 1.94}
# {'loss': 7.5294, 'grad_norm': 11.218135833740234, 'learning_rate': 2.913372292884153e-05, 'epoch': 2.26}
# {'loss': 7.4944, 'grad_norm': 9.016424179077148, 'learning_rate': 2.569611550360949e-05, 'epoch': 2.58}
# {'loss': 7.439, 'grad_norm': 7.707988262176514, 'learning_rate': 2.225850807837745e-05, 'epoch': 2.91}
# {'loss': 7.3573, 'grad_norm': 9.342020988464355, 'learning_rate': 1.8820900653145413e-05, 'epoch': 3.23}
# {'loss': 7.347, 'grad_norm': 7.793463706970215, 'learning_rate': 1.5383293227913374e-05, 'epoch': 3.55}
# {'loss': 7.3217, 'grad_norm': 10.551172256469727, 'learning_rate': 1.1945685802681335e-05, 'epoch': 3.88}
# {'loss': 7.2923, 'grad_norm': 9.86595630645752, 'learning_rate': 8.508078377449295e-06, 'epoch': 4.2}
# {'loss': 7.2499, 'grad_norm': 10.050202369689941, 'learning_rate': 5.070470952217257e-06, 'epoch': 4.52}
# {'loss': 7.2724, 'grad_norm': 9.589643478393555, 'learning_rate': 1.6328635269852184e-06, 'epoch': 4.85}
# {'train_runtime': 184.6764, 'train_samples_per_second': 536.073, 'train_steps_per_second': 16.759, 'train_loss': 7.630021467809724, 'epoch': 5.0}
# [done] baseline saved to: ./checkpoints/start=per_node__scheme=degree/paper_1990_seed

# %%
# %%bash
# cd /root/science-society
#
# START_MODE="per_node"
# PER_NODE_SCHEME="degree"
# if [ "${START_MODE}" = "per_node" ]; then
#   MODE_TAG="start=${START_MODE}__scheme=${PER_NODE_SCHEME}"
# else
#   MODE_TAG="start=${START_MODE}"
# fi
#
# init_y=1990
# DATASET_DIR="./datasets/${MODE_TAG}"
# CKPT_DIR="./checkpoints/${MODE_TAG}"
# mkdir -p "${CKPT_DIR}"
#
# d="news"
# python scripts/train_annual_2stage_preinit.py \
#   --init_dir "${CKPT_DIR}/${d}_${init_y}_seed" \
#   --node_vocab_txt ./tokenizer/concept_vocab_encoded.txt \
#   --years 1991 \
#   --dataset_template "${DATASET_DIR}/${d}_{year}" \
#   --output_base_dir "${CKPT_DIR}/${d}_annual" \
#   --exact_k_masks 1 \
#   --num_train_epochs 2 \
#   --learning_rate 1e-5 \
#
# d="paper"
# python scripts/train_annual_2stage_preinit.py \
#   --init_dir "${CKPT_DIR}/${d}_${init_y}_seed" \
#   --node_vocab_txt ./tokenizer/concept_vocab_encoded.txt \
#   --years 1991 \
#   --dataset_template "${DATASET_DIR}/${d}_{year}" \
#   --output_base_dir "${CKPT_DIR}/${d}_annual" \
#   --exact_k_masks 1 \
#   --num_train_epochs 2 \
#   --learning_rate 1e-5
# Out:
# [plan]
#   - 1991: ./datasets/start=per_node__scheme=degree/news_1991
# [vocab] node tokens: 22577
#
# ==============================
# [year 1991] init_dir = ./checkpoints/start=per_node__scheme=degree/news_1990_seed
# [year 1991] dataset_dir = ./datasets/start=per_node__scheme=degree/news_1991
# [year 1991] node_token_ids in tokenizer: 22577
# Map: 100%|██████████| 20000/20000 [00:00<00:00, 29246.64 examples/s]
# 100%|██████████| 1238/1238 [01:16<00:00, 16.21it/s]
# {'loss': 7.1423, 'grad_norm': 15.847662925720215, 'learning_rate': 8.92519346517627e-06, 'epoch': 0.32}
# {'loss': 6.5609, 'grad_norm': 14.771403312683105, 'learning_rate': 7.2055030094582974e-06, 'epoch': 0.65}
# {'loss': 6.3241, 'grad_norm': 14.427084922790527, 'learning_rate': 5.485812553740327e-06, 'epoch': 0.97}
# {'loss': 6.1209, 'grad_norm': 15.409149169921875, 'learning_rate': 3.7661220980223563e-06, 'epoch': 1.29}
# {'loss': 6.0364, 'grad_norm': 15.750102996826172, 'learning_rate': 2.0464316423043853e-06, 'epoch': 1.62}
# {'loss': 6.0232, 'grad_norm': 16.35198974609375, 'learning_rate': 3.2674118658641445e-07, 'epoch': 1.94}
# {'train_runtime': 76.3532, 'train_samples_per_second': 518.642, 'train_steps_per_second': 16.214, 'train_loss': 6.355736592282001, 'epoch': 2.0}
# [year 1991] saved: ./checkpoints/start=per_node__scheme=degree/news_annual/1991
#
# [done] all years finished.
# [done] final checkpoint: ./checkpoints/start=per_node__scheme=degree/news_annual/1991
# [plan]
#   - 1991: ./datasets/start=per_node__scheme=degree/paper_1991
# [vocab] node tokens: 22577
#
# ==============================
# [year 1991] init_dir = ./checkpoints/start=per_node__scheme=degree/paper_1990_seed
# [year 1991] dataset_dir = ./datasets/start=per_node__scheme=degree/paper_1991
# [year 1991] node_token_ids in tokenizer: 22577
# Map: 100%|██████████| 20000/20000 [00:00<00:00, 25617.17 examples/s]
# 100%|██████████| 1238/1238 [01:16<00:00, 16.23it/s]
# {'loss': 7.5964, 'grad_norm': 15.339761734008789, 'learning_rate': 8.92519346517627e-06, 'epoch': 0.32}
# {'loss': 7.4909, 'grad_norm': 14.729979515075684, 'learning_rate': 7.2055030094582974e-06, 'epoch': 0.65}
# {'loss': 7.5198, 'grad_norm': 14.912036895751953, 'learning_rate': 5.485812553740327e-06, 'epoch': 0.97}
# {'loss': 7.4521, 'grad_norm': 17.014968872070312, 'learning_rate': 3.7661220980223563e-06, 'epoch': 1.29}
# {'loss': 7.4064, 'grad_norm': 16.822351455688477, 'learning_rate': 2.0464316423043853e-06, 'epoch': 1.62}
# {'loss': 7.4745, 'grad_norm': 16.453340530395508, 'learning_rate': 3.2674118658641445e-07, 'epoch': 1.94}
# {'train_runtime': 76.2945, 'train_samples_per_second': 519.041, 'train_steps_per_second': 16.227, 'train_loss': 7.485237158558095, 'epoch': 2.0}
# [year 1991] saved: ./checkpoints/start=per_node__scheme=degree/paper_annual/1991
#
# [done] all years finished.
# [done] final checkpoint: ./checkpoints/start=per_node__scheme=degree/paper_annual/1991

# %%
# %%bash
# cd /root/science-society
#
# START_MODE="per_node"
# PER_NODE_SCHEME="degree"
# if [ "${START_MODE}" = "per_node" ]; then
#   MODE_TAG="start=${START_MODE}__scheme=${PER_NODE_SCHEME}"
# else
#   MODE_TAG="start=${START_MODE}"
# fi
#
# CORPUS_DIR="./corpus/${MODE_TAG}"
# CKPT_DIR="./checkpoints/${MODE_TAG}"
# OUT_DIR="./outputs/${MODE_TAG}"
# mkdir -p "${OUT_DIR}"
#
# python scripts/predict_neighbors_by_distance.py \
#   --years 1991 \
#   --domains news paper \
#   --ckpt_root "${CKPT_DIR}" \
#   --corpus_root "${CORPUS_DIR}" \
#   --node_vocab_txt ./tokenizer/concept_vocab_encoded.txt \
#   --targets automation productivity health_care legislation \
#   --distance 1 \
#   --topk 30 \
#   --max_contexts 1000 \
#   --out_root "${OUT_DIR}/mask_pred" \
# Out:
# [INFO] loaded node vocab: 22577
# [DEBUG-ONE] target=automation distance=1 len(tokens)=20 i=9 pos=10
# [DEBUG-ONE] mask_idx=11 input_id@mask_idx=103 (mask_id=103)
# [DEBUG-CTX] used=0 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['bankers_associations', 'criminal_investigations', 'fraud_prevention', 'artificial_intelligence', 'company_profiles', 'consultants', 'competition', 'regulations', 'pilot_projects', 'automation']
# [DEBUG-CTX] sample ids   : [31885, 34601, 37719, 31461, 33832, 22283, 2971, 7040, 44098, 19309]
# [DEBUG-CTX] target_token_id: 19309
# [DEBUG-CTX] used=1 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['strategic_planning', 'research_&_development', 'cities', 'state_laws', 'central_banks', 'chief_operating_officers', 'retirement', 'comptrollers', 'society', 'retirement']
# [DEBUG-CTX] sample ids   : [47864, 45750, 3655, 47652, 33046, 33216, 5075, 33914, 2554, 5075]
# [DEBUG-CTX] target_token_id: 19309
# [DEBUG-CTX] used=2 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['banking', 'employees', 'product_differentiation', 'employees', 'embezzlement', 'criminal_sentences', 'criminal_investigations', 'banking_industry', 'electronic_filing', 'home_mortgage_disclosure_act']
# [DEBUG-CTX] sample ids   : [8169, 5126, 44744, 5126, 36301, 34608, 34601, 31887, 36222, 38943]
# [DEBUG-CTX] target_token_id: 19309
# [DEBUG] used=1000 unique_scores=1272 ranked_len=1272 topk=30
# [DEBUG-ONE] target=automation distance=1 len(tokens)=20 i=7 pos=8
# [DEBUG-ONE] mask_idx=9 input_id@mask_idx=103 (mask_id=103)
# [DEBUG-CTX] used=0 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['positron_emission_tomography', 'strengths_and_weaknesses', 'marketing_research', 'telephone_survey', 'seekers', 'work_(physics)', 'robotic_arm', 'automation', '[MASK]', 'politics']
# [DEBUG-CTX] sample ids   : [44408, 47879, 41288, 48466, 24071, 50187, 46002, 19309, 103, 4331]
# [DEBUG-CTX] target_token_id: 19309
# [DEBUG-CTX] used=1 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['dielectric', 'salient', 'automation', '[MASK]', 'air_conditioning', 'wind_engineering', 'monte_carlo_method', 'electric_power_transmission', 'inference', 'instrumental_variable']
# [DEBUG-CTX] sample ids   : [35382, 46166, 19309, 103, 30939, 50119, 42083, 36135, 28937, 39696]
# [DEBUG-CTX] target_token_id: 19309
# [DEBUG-CTX] used=2 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['polymer', 'gadolinium', 'detector', 'contrast_medium', 'cancer', 'acute_illness', 'perception', 'closeness', 'rayleigh_scattering', 'speckle_pattern']
# [DEBUG-CTX] sample ids   : [17782, 37903, 19034, 34279, 4456, 30755, 10617, 28398, 45414, 47433]
# [DEBUG-CTX] target_token_id: 19309
# [DEBUG] used=313 unique_scores=967 ranked_len=967 topk=30
# [OK] saved ./outputs/start=per_node__scheme=degree/mask_pred/dist=1/year=1991/target=automation.tsv
# [DEBUG-ONE] target=productivity distance=1 len(tokens)=20 i=4 pos=5
# [DEBUG-ONE] mask_idx=6 input_id@mask_idx=103 (mask_id=103)
# [DEBUG-CTX] used=0 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['bank_accounts', 'bank_automation', 'computer_terminals', 'mergers_&_acquisitions', 'productivity', '[MASK]', 'women', 'demographics', 'banks', 'loan_losses']
# [DEBUG-CTX] sample ids   : [31847, 31850, 34007, 41633, 15836, 103, 2308, 28321, 5085, 40876]
# [DEBUG-CTX] target_token_id: 15836
# [DEBUG-CTX] used=1 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['institutional_investments', 'world_markets_(wsj)', 'prices', 'personal_computers', 'health_care', 'medical_technology', 'health_care', 'physicians', 'cardiovascular_disease', 'medical_research']
# [DEBUG-CTX] sample ids   : [39686, 50240, 7597, 43840, 38610, 41522, 38610, 11572, 32883, 41514]
# [DEBUG-CTX] target_token_id: 15836
# [DEBUG-CTX] used=2 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['branch_banking', 'feasibility_studies', 'profitability', 'automation', 'government_aid', 'factories', 'assembly_lines', 'factories', 'globalization', 'productivity']
# [DEBUG-CTX] sample ids   : [32466, 37121, 44810, 19309, 38280, 11123, 31509, 11123, 24370, 15836]
# [DEBUG-CTX] target_token_id: 15836
# [DEBUG] used=1000 unique_scores=822 ranked_len=822 topk=30
# [DEBUG-ONE] target=productivity distance=1 len(tokens)=20 i=14 pos=15
# [DEBUG-ONE] mask_idx=16 input_id@mask_idx=103 (mask_id=103)
# [DEBUG-CTX] used=0 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['space_(punctuation)', 'pace', 'position_(finance)', 'diffusion', "schrödinger's_cat", 'calculus_(dental)', 'computational_linguistics', 'closure_(psychology)', 'trilogy', 'ontology']
# [DEBUG-CTX] sample ids   : [47343, 6393, 44392, 19241, 46301, 32721, 33929, 33504, 11544, 43074]
# [DEBUG-CTX] target_token_id: 15836
# [DEBUG-CTX] used=1 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['network_packet', 'productivity', '[MASK]', 'task_(project_management)', 'congruence_(geometry)', 'meaning_(existential)', 'public_health', 'sociology_of_knowledge', 'criticism', 'knowledge_base']
# [DEBUG-CTX] sample ids   : [42576, 15836, 103, 48341, 34098, 41418, 45028, 47190, 6256, 40256]
# [DEBUG-CTX] target_token_id: 15836
# [DEBUG-CTX] used=2 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['formal_description', 'finite-state_machine', 'flexibility_(engineering)', 'obsolescence', 'productivity', '[MASK]', 'property_rights', 'wright', 'criticism', 'public_health']
# [DEBUG-CTX] sample ids   : [37644, 37316, 37421, 42915, 15836, 103, 44870, 6119, 6256, 45028]
# [DEBUG-CTX] target_token_id: 15836
# [DEBUG] used=211 unique_scores=671 ranked_len=671 topk=30
# [OK] saved ./outputs/start=per_node__scheme=degree/mask_pred/dist=1/year=1991/target=productivity.tsv
# [DEBUG-ONE] target=health_care distance=1 len(tokens)=20 i=4 pos=5
# [DEBUG-ONE] mask_idx=6 input_id@mask_idx=103 (mask_id=103)
# [DEBUG-CTX] used=0 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['institutional_investments', 'world_markets_(wsj)', 'prices', 'personal_computers', 'health_care', '[MASK]', 'health_care', 'physicians', 'cardiovascular_disease', 'medical_research']
# [DEBUG-CTX] sample ids   : [39686, 50240, 7597, 43840, 38610, 103, 38610, 11572, 32883, 41514]
# [DEBUG-CTX] target_token_id: 38610
# [DEBUG-CTX] used=1 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['institutional_investments', 'world_markets_(wsj)', 'prices', 'personal_computers', 'health_care', 'medical_technology', 'health_care', '[MASK]', 'cardiovascular_disease', 'medical_research']
# [DEBUG-CTX] sample ids   : [39686, 50240, 7597, 43840, 38610, 41522, 38610, 103, 32883, 41514]
# [DEBUG-CTX] target_token_id: 38610
# [DEBUG-CTX] used=2 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['marketing', 'small_business', 'freedom_of_speech', 'recordings_(audio)', 'telephones', 'stocks_and_bonds', 'automation', 'bankruptcy', 'collateral', 'enhanced_oil_recovery']
# [DEBUG-CTX] sample ids   : [5821, 47009, 37756, 45499, 48468, 47820, 19309, 10528, 24172, 36495]
# [DEBUG-CTX] target_token_id: 38610
# [DEBUG] used=161 unique_scores=330 ranked_len=330 topk=30
# [DEBUG-ONE] target=health_care distance=1 len(tokens)=20 i=16 pos=17
# [DEBUG-ONE] mask_idx=18 input_id@mask_idx=103 (mask_id=103)
# [DEBUG-CTX] used=0 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['zeroth_law_of_thermodynamics', 'class_(philosophy)', 'scaling', 'brownian_motion', 'uniqueness', 'discrete_time_and_continuous_time', 'second_moment_of_area', 'moment_(physics)', 'politics', 'corporate_governance']
# [DEBUG-CTX] sample ids   : [50323, 33406, 25169, 32552, 49403, 35581, 46413, 42031, 4331, 34397]
# [DEBUG-CTX] target_token_id: 38610
# [DEBUG-CTX] used=1 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['controller_(irrigation)', 'solvent', 'yield_(engineering)', 'constant_(computer_programming)', 'net_(polyhedron)', 'perspective_(graphical)', 'delphi_method', 'first_line', 'line_management', 'order_(exchange)']
# [DEBUG-CTX] sample ids   : [34302, 23735, 50287, 34147, 42549, 43870, 35153, 37362, 40742, 43210]
# [DEBUG-CTX] target_token_id: 38610
# [DEBUG-CTX] used=2 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['contrast_(vision)', 'microcirculation', 'perfusion', 'image_(mathematics)', 'hearing_aid', 'frequency_response', 'substructure', 'resolution_(logic)', 'propagation_of_uncertainty', 'training_set']
# [DEBUG-CTX] sample ids   : [34278, 41731, 43776, 39313, 38644, 37775, 48017, 45798, 44855, 49009]
# [DEBUG-CTX] target_token_id: 38610
# [DEBUG] used=320 unique_scores=957 ranked_len=957 topk=30
# [OK] saved ./outputs/start=per_node__scheme=degree/mask_pred/dist=1/year=1991/target=health_care.tsv
# [DEBUG-ONE] target=legislation distance=1 len(tokens)=20 i=12 pos=13
# [DEBUG-ONE] mask_idx=14 input_id@mask_idx=103 (mask_id=103)
# [DEBUG-CTX] used=0 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['automation', 'interest_rates', 'profits', 'information_services', 'gasoline_taxes', 'information_services', 'airline_security', 'data_processing', 'polls_&_surveys', 'operating_costs']
# [DEBUG-CTX] sample ids   : [19309, 39818, 11372, 39600, 37972, 39600, 30976, 34943, 44301, 43101]
# [DEBUG-CTX] target_token_id: 6094
# [DEBUG-CTX] used=1 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['teams', 'automation', 'tax_increases', 'data_processing', 'customer_information_files', 'banking_industry', 'fraud', 'customers', 'legislation', '[MASK]']
# [DEBUG-CTX] sample ids   : [2780, 19309, 48357, 34943, 34815, 31887, 9861, 6304, 6094, 103]
# [DEBUG-CTX] target_token_id: 6094
# [DEBUG-CTX] used=2 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['self_evaluation', 'cash_management', 'health_care_industry', 'robots', 'decisions_and_verdicts', 'cable_television', 'directories', 'editorials', 'recording_equipment', 'legislation']
# [DEBUG-CTX] sample ids   : [46547, 32942, 38614, 13507, 35059, 32693, 35541, 36052, 45496, 6094]
# [DEBUG-CTX] target_token_id: 6094
# [DEBUG] used=1000 unique_scores=735 ranked_len=735 topk=30
# [DEBUG-ONE] target=legislation distance=1 len(tokens)=20 i=3 pos=4
# [DEBUG-ONE] mask_idx=5 input_id@mask_idx=103 (mask_id=103)
# [DEBUG-CTX] used=0 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['macromolecule', 'limiting', 'cybernetics', 'legislation', '[MASK]', 'pooling', 'autoregressive_model', 'radar', 'shading', 'ambiguity']
# [DEBUG-CTX] sample ids   : [41076, 14879, 34844, 6094, 103, 44360, 31747, 7217, 46729, 27637]
# [DEBUG-CTX] target_token_id: 6094
# [DEBUG-CTX] used=1 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['waveguide', 'sensitivity_(control_systems)', 'minimum_cut', 'linear_programming', 'repetition_(rhetorical_device)', 'quality_(philosophy)', 'integer_programming', 'legislation', '[MASK]', 'photoelectric_effect']
# [DEBUG-CTX] sample ids   : [50003, 46611, 41891, 40761, 45728, 45177, 39723, 6094, 103, 43999]
# [DEBUG-CTX] target_token_id: 6094
# [DEBUG-CTX] used=2 len(ids)=20 unk_cnt=0 unk_rate=0.000
# [DEBUG-CTX] sample tokens: ['field_(mathematics)', 'petroleum_industry', 'legislation', '[MASK]', 'cortex_(anatomy)', 'receptive_field', 'pattern_recognition_(psychology)', 'microprocessor', 'alarm', 'identification_(biology)']
# [DEBUG-CTX] sample ids   : [37223, 43889, 6094, 103, 34441, 45482, 43644, 41761, 8598, 39287]
# [DEBUG-CTX] target_token_id: 6094
# [DEBUG] used=97 unique_scores=533 ranked_len=533 topk=30
# [OK] saved ./outputs/start=per_node__scheme=degree/mask_pred/dist=1/year=1991/target=legislation.tsv

# %%
import numpy as np, pandas as pd

targets = [
    "automation", "productivity", "health_care", "legislation",
]

base = "/root/science-society/outputs/start=per_node__scheme=degree/mask_pred/dist=1/year=1991"
for t in targets:
    path = f"{base}/target={t}.tsv"
    print(f"\n============================== TARGET: {t} ==============================")
    df = pd.read_csv(path, sep="\t")
    display(df.head(20))
# Out:
# ============================== TARGET: automation ==============================
#     rank     news_neighbor  news_avg_prob        paper_neighbor  \
# 0      1           poultry       0.386409      video_production
# 1      2              golf       0.377192              downtown
# 2      3          warships       0.245459              drilling
# 3      4    tax_incentives       0.150103         cost_estimate
# 4      5            speech       0.117597                 queue
# 5      6   public_hearings       0.112206     space_exploration
# 6      7          renminbi       0.105525       library_catalog
# 7      8      golf_courses       0.081944         video_editing
# 8      9         railroads       0.076622            camouflage
# 9     10        complaints       0.068055     critical_thinking
# 10    11          firearms       0.067680                 crash
# 11    12         investors       0.059687            amino_acid
# 12    13         influence       0.056877               fishing
# 13    14     air_pollution       0.056042  emergency_management
# 14    15  clocks_&_watches       0.049769              elevator
# 15    16            rubber       0.049701            excavation
# 16    17            tennis       0.044557                  verb
# 17    18     certification       0.041165         diesel_engine
# 18    19             theft       0.040666            blood_flow
# 19    20   transit_systems       0.039831      air_conditioning
#
#     paper_avg_prob
# 0         0.157205
# 1         0.081776
# 2         0.073364
# 3         0.046444
# 4         0.042701
# 5         0.038435
# 6         0.038322
# 7         0.034282
# 8         0.034101
# 9         0.030201
# 10        0.028831
# 11        0.028752
# 12        0.028417
# 13        0.027553
# 14        0.027007
# 15        0.025835
# 16        0.025739
# 17        0.025636
# 18        0.025072
# 19        0.024510
# ============================== TARGET: productivity ==============================
#     rank          news_neighbor  news_avg_prob                paper_neighbor  \
# 0      1                 clergy       0.275154                    recreation
# 1      2            health_care       0.100561                 food_products
# 2      3                  bonds       0.087122                   real_estate
# 3      4           demographics       0.084714                food_packaging
# 4      5            indictments       0.070439               property_rights
# 5      6          air_pollution       0.066885                 marketing_mix
# 6      7                 trucks       0.065691                       polymer
# 7      8          globalization       0.061236                        estate
# 8      9              subsidies       0.052057                      humidity
# 9     10              influence       0.047745             radioactive_waste
# 10    11            restaurants       0.047190         intellectual_property
# 11    12                sensors       0.046771                      workload
# 12    13       roads_&_highways       0.043479            demand_forecasting
# 13    14  building_construction       0.042007                          crop
# 14    15                privacy       0.041953  principal_component_analysis
# 15    16   consumer_electronics       0.041262                 cost_estimate
# 16    17      energy_efficiency       0.040558                 real_property
# 17    18                  tires       0.038161                   food_safety
# 18    19             navigation       0.037750               fault_tolerance
# 19    20    technology_transfer       0.037408                      drainage
#
#     paper_avg_prob
# 0         0.243869
# 1         0.088015
# 2         0.063439
# 3         0.049514
# 4         0.038939
# 5         0.038795
# 6         0.038467
# 7         0.037392
# 8         0.037056
# 9         0.033142
# 10        0.028193
# 11        0.027211
# 12        0.022096
# 13        0.022028
# 14        0.021024
# 15        0.020818
# 16        0.020238
# 17        0.019275
# 18        0.019190
# 19        0.018969
# ============================== TARGET: health_care ==============================
#     rank                         news_neighbor  news_avg_prob  \
# 0      1                       motion_pictures       0.069192
# 1      2                                 heart       0.063610
# 2      3                acquisitions_&_mergers       0.060948
# 3      4                families_&_family_life       0.050937
# 4      5                                 books       0.048548
# 5      6                       stock_exchanges       0.045253
# 6      7                           health_care       0.044998
# 7      8                    medical_technology       0.041020
# 8      9                                robots       0.040828
# 9     10                   international_trade       0.040127
# 10    11                             liability       0.039681
# 11    12                cardiovascular_disease       0.036909
# 12    13  motion_picture_directors_&_producers       0.036542
# 13    14                               layoffs       0.030374
# 14    15                          stock_prices       0.028944
# 15    16                            psychology       0.028107
# 16    17                             computers       0.023407
# 17    18                            net_losses       0.023089
# 18    19               artificial_intelligence       0.022023
# 19    20                      medical_research       0.021311
#
#                    paper_neighbor  paper_avg_prob
# 0                           lease        0.103274
# 1                      acute_pain        0.089652
# 2                right_hemisphere        0.067478
# 3                   supreme_court        0.062931
# 4                        nosology        0.062260
# 5                        teamwork        0.051941
# 6                        outbreak        0.048319
# 7           management_accounting        0.047588
# 8                   manufacturing        0.043547
# 9               national_accounts        0.037417
# 10                      dysphagia        0.031349
# 11                   chronic_pain        0.030484
# 12                pain_management        0.029473
# 13               eating_disorders        0.028217
# 14                 retail_banking        0.028042
# 15              graduate_students        0.024442
# 16  accounting_information_system        0.022361
# 17                        habitat        0.021726
# 18                         kidney        0.021552
# 19          computer_data_storage        0.020825
# ============================== TARGET: legislation ==============================
#     rank        news_neighbor  news_avg_prob           paper_neighbor  \
# 0      1        accreditation       0.177031           nuclear_weapon
# 1      2              exports       0.152879                    ozone
# 2      3               grants       0.086077               regression
# 3      4        professionals       0.078219                 foraging
# 4      5           algorithms       0.076359           urban_planning
# 5      6             landfill       0.072879         nuclear_material
# 6      7              poultry       0.067716  transportation_planning
# 7      8            recycling       0.062029     resistance_(ecology)
# 8      9       reorganization       0.060299                    drama
# 9     10            shipments       0.046145                addiction
# 10    11        redistricting       0.043640            nuclear_power
# 11    12  energy_conservation       0.040302       strategic_planning
# 12    13           conspiracy       0.040290          nuclear_reactor
# 13    14                codes       0.039256     emergency_management
# 14    15             bacteria       0.038505                   cancer
# 15    16                 bids       0.038489                pollution
# 16    17            nutrition       0.036715        telephone_network
# 17    18   elementary_schools       0.034934         food_consumption
# 18    19          engineering       0.034160            air_pollution
# 19    20          legislation       0.032992                watershed
#
#     paper_avg_prob
# 0         0.264267
# 1         0.082742
# 2         0.082009
# 3         0.073079
# 4         0.064802
# 5         0.054423
# 6         0.053850
# 7         0.032839
# 8         0.032238
# 9         0.031689
# 10        0.030287
# 11        0.028940
# 12        0.027029
# 13        0.026107
# 14        0.024328
# 15        0.023745
# 16        0.023183
# 17        0.023179
# 18        0.021880
# 19        0.020897

# %%
# %%bash
# cd /root/science-society
#
# python scripts/check_conditional_from_corpus.py \
#   --corpus ./corpus/news_1991.txt \
#   --targets automation productivity health_care legislation \
#   --distance 1 \
#   --topk 30
#
# python scripts/check_conditional_from_corpus.py \
#   --corpus ./corpus/paper_1991.txt \
#   --targets automation productivity health_care legislation \
#   --distance 1 \
#   --topk 30
# Out:
# [CORPUS] ./corpus/news_1991.txt
# [DIST] distance=1
# [PRIOR] total_tokens=400000 unique=1664
# [PRIOR] top30[:10]=['automation', 'banks', 'software', 'bank_automation', 'computers', 'banking_industry', 'personal_computers', 'technology', 'cost_control', 'information_systems']
#
# ===== TARGET=automation =====
# occurrences_in_lines=12050  valid_positions=11457
# cond_unique=931
# cond_top30[:10]=['lawn_&_garden_equipment', 'state_elections', 'auctions', 'education', 'robbery', 'corrections', 'child_support', 'profit_margins', 'trucking_industry', 'trust_companies']
# top1_same_as_prior=False (cond_top1=lawn_&_garden_equipment, prior_top1=automation)
# top30_overlap_with_prior=0.067 (|∩|=2)
# JSD(cond || prior)=0.194271
#
# ===== TARGET=productivity =====
# occurrences_in_lines=1815  valid_positions=1722
# cond_unique=144
# cond_top30[:10]=['banking_industry', 'relationship_banking', 'risk', 'budgeting', 'equipment', 'workers', 'computer_aided_software_engineering', 'credit_cards', 'telemarketing', 'foreign_investment']
# top1_same_as_prior=False (cond_top1=banking_industry, prior_top1=automation)
# top30_overlap_with_prior=0.133 (|∩|=4)
# JSD(cond || prior)=0.396500
#
# ===== TARGET=health_care =====
# occurrences_in_lines=168  valid_positions=161
# cond_unique=11
# cond_top30[:10]=['physicians', 'computers', 'emergency_medical_care', 'cardiovascular_disease', 'personal_computers', 'heart_attacks', 'medical_technology', 'robots', 'health_care_industry', 'neural_networks']
# top1_same_as_prior=False (cond_top1=physicians, prior_top1=automation)
# top30_overlap_with_prior=0.133 (|∩|=4)
# JSD(cond || prior)=0.632466
#
# ===== TARGET=legislation =====
# occurrences_in_lines=1196  valid_positions=1148
# cond_unique=94
# cond_top30[:10]=['service_introduction', 'customers', 'productivity', 'cellular_telephones', 'federal_government', 'trials', 'banks', 'bankruptcy', 'consumer_protection', 'airlines']
# top1_same_as_prior=False (cond_top1=service_introduction, prior_top1=automation)
# top30_overlap_with_prior=0.167 (|∩|=5)
# JSD(cond || prior)=0.480538
#
#
# [CORPUS] ./corpus/paper_1991.txt
# [DIST] distance=1
# [PRIOR] total_tokens=400000 unique=12657
# [PRIOR] top30[:10]=['control_(management)', 'image_(mathematics)', 'perspective_(graphical)', 'selection_(genetic_algorithm)', 'variety_(cybernetics)', 'class_(philosophy)', 'process_(computing)', 'politics', 'gene', 'set_(abstract_data_type)']
#
# ===== TARGET=automation =====
# occurrences_in_lines=330  valid_positions=313
# cond_unique=248
# cond_top30[:10]=['chain_(unit)', 'monochrome', 'sight', 'profiling_(computer_programming)', 'unit_(ring_theory)', 'nonlinear_system', 'encyclopedia', 'computer_graphics', 'submarine_pipeline', 'scripting_language']
# top1_same_as_prior=False (cond_top1=chain_(unit), prior_top1=control_(management))
# top30_overlap_with_prior=0.033 (|∩|=1)
# JSD(cond || prior)=0.537290
#
# ===== TARGET=productivity =====
# occurrences_in_lines=224  valid_positions=211
# cond_unique=165
# cond_top30[:10]=['independence_(probability_theory)', 'factory_(object-oriented_programming)', 'parametric_statistics', 'asset_(computer_security)', 'value_engineering', 'property_rights', 'information_technology', 'activity-based_costing', 'contrast_(vision)', 'loyalty']
# top1_same_as_prior=False (cond_top1=independence_(probability_theory), prior_top1=control_(management))
# top30_overlap_with_prior=0.033 (|∩|=1)
# JSD(cond || prior)=0.593670
#
# ===== TARGET=health_care =====
# occurrences_in_lines=338  valid_positions=320
# cond_unique=258
# cond_top30[:10]=['white_paper', 'heuristic', 'advisory_committee', 'interview', 'multivariate_statistics', 'futurist', 'pain_relief', 'medical_diagnosis', 'relation_(database)', 'product_(mathematics)']
# top1_same_as_prior=False (cond_top1=white_paper, prior_top1=control_(management))
# top30_overlap_with_prior=0.000 (|∩|=0)
# JSD(cond || prior)=0.583817
#
# ===== TARGET=legislation =====
# occurrences_in_lines=102  valid_positions=97
# cond_unique=79
# cond_top30[:10]=['hearing_aid', 'fossil_fuel', 'phenomenon', 'identification_(biology)', 'scope_(computer_science)', 'state_(computer_science)', 'commodity', 'consumerism', 'radioactive_waste', 'collusion']
# top1_same_as_prior=False (cond_top1=hearing_aid, prior_top1=control_(management))
# top30_overlap_with_prior=0.033 (|∩|=1)
# JSD(cond || prior)=0.629172
